# %%
# %cd pk-kavin
# Install your dependencies
# !pip install torch torchvision torchaudio
# !pip install datasets tokenizers tqdm tensorboard
# Out:
# [Errno 2] No such file or directory: 'pk-kavin'
# /kaggle/working
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.6 MB/s eta 0:00:0000:010:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.3 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
from tokenizers import Tokenizer

tokenizer_src = Tokenizer.from_file("/kaggle/input/pk-kavin/tokenizer_en.json")
tokenizer_tgt = Tokenizer.from_file("/kaggle/input/pk-kavin/tokenizer_ta.json")

# %%
#import sys
#sys.path.append("/kaggle/input/transformers-pk")
#import torch
#from model import build_transformer
#from config import get_config

# Load config (must be the same one you used earlier)
#config = get_config()

# Rebuild the same transformer architecture
##   src_vocab_size=tokenizer_src.get_vocab_size(),
  #  target_vocab_size=tokenizer_tgt.get_vocab_size(),
   # src_seq_len=config['seq_len'],
    #d_model=config['d_model'],
   # N=4,
    #h=config['h'],
    #dropout=config['dropout']
#).to("cuda")

# === Load previous weights here ===
#weights_path = "/kaggle/input/trained-weights/weights07.pt"
#checkpoint = torch.load(weights_path, map_location="cuda")
#model.load_state_dict(checkpoint)

#print("Loaded weights from previous training!")

# %%
# !cp -r /kaggle/input/pk-kavin/* /kaggle/working/
# %cd /kaggle/working
# !python train.py
# Out:
# /kaggle/working
# 2025-09-29 09:19:53.100555: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759137593.122369     130 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759137593.128957     130 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Using device cuda
# README.md: 100%|██████████████████████████████| 70.0/70.0 [00:00<00:00, 344kB/s]
# corpus.bcn.train 166k.csv: 100%|███████████| 99.2M/99.2M [00:05<00:00, 18.5MB/s]
# en-ta train 118k.csv: 100%|████████████████| 75.8M/75.8M [00:05<00:00, 14.7MB/s]
# corpus.bcn.dev%201k.csv: 589kB [00:00, 109MB/s]
# ...

# %%
#!mkdir -p /kaggle/working/output
#!cp /kaggle/working/weights.zip /kaggle/working/output/
# Out:
# cp: cannot stat '/kaggle/working/weights.zip': No such file or directory

# %%
#from IPython.display import HTML

# Path to your zip file
#zip_path = "/kaggle/working/weights_part2.zip"

# Create a clickable download link
#HTML(f'<a href="{zip_path}" download>Click here to download weights.zip</a>')
# Out:
# <a href="/kaggle/working/weights_part2.zip" download>Click here to download weights.zip</a>

# %%
#from config import get_config, get_weights_file_path
#from train import train_model
#from kaggle_secrets import UserSecretsClient
#from IPython.display import FileLink

# Get base config
#config = get_config()
#/kaggle/input/trained-weights/weights07.p
# Point to the downloaded checkpoint from epoch 7
# Make sure you have uploaded weights7.pt to your Kaggle input dataset or working dir
#config['preload'] = "07"   # Explicitly tell train.py to resume from this file
#config['model_folder'] = "/kaggle/input/trained-weights"  # Where weights will be saved
#config['num_epochs'] = 20           # Continue training until epoch 20

# Run training (it will pick up epoch, optimizer state, global step)
#trained_model = train_model(config)

# After training, save final model for download
#final_path = "/kaggle/working/final_weights.pt"
#torch.save({
 #   'model_state_dict': trained_model.state_dict()
#}, final_path)

#from IPython.display import FileLink
#FileLink(final_path)

# %%
#import os
#checkpoint_path = "/kaggle/working/weights7.pt"
#start_epoch = 0

#if os.path.exists(checkpoint_path):
 #   checkpoint = torch.load(checkpoint_path, map_location="cuda" if torch.cuda.is_available() else "cpu")
  #  if "model_state_dict" in checkpoint:
   #     model.load_state_dict(checkpoint["model_state_dict"])
    #if "optimizer_state_dict" in checkpoint:
        #optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    #if "epoch" in checkpoint:
     #   start_epoch = checkpoint["epoch"] + 1  # Resume from next epoch

#print(f"Resuming training from epoch {start_epoch}")

#!python train.py
# --- Continue Training ---
#for epoch in range(start_epoch, 20):  # Continue till epoch 20
    #train_loss = train_one_epoch(model, optimizer, epoch)  # <-- This should be in your train.py
#print("Training complete!")

# %%
#import torch
#checkpoint = torch.load("/kaggle/working/weights09.pt", map_location="cpu")
#model.load_state_dict(checkpoint["model_state_dict"])

# Save 
#torch.save({
 #   "epoch": epoch,
  #  "model_state_dict": model.state_dict(),
   # "optimizer_state_dict": optimizer.state_dict(),
    #"loss": loss
#}, f"/kaggle/working/weights7.pt")

# %%
#from kaggle_secrets import UserSecretsClient
#from IPython.display import FileLink

# This will create a link to download
#FileLink(r'model_weights.pth')
